# %% [markdown]
# <a href="https://colab.research.google.com/github/DevTedd/Individual-Project-Week-4-Moringa/blob/main/Moringa_Data_Science_Prep_W4_Independent_Project_2021_09_Ted_Kimani_DataProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Friday: Independent Project - Week 4

# %% [markdown]
# In this week's independent project, you will be working as a data scientist working for an electric car-sharing service company. You have been tasked to process stations data to understand electric car usage over time by solving for the following research question;
#
# # Research Question
#
# Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
# Bonus Questions (Optional)
#
# What is the most popular hour for returning cars?
# What station is the most popular?
# Overall?
# At the most popular picking hour?
# What postal code is the most popular for picking up Blue cars? Does the most popular station belong to that postal code?
# Overall?
# At the most popular picking hour?
# Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars?
# Your final deliverable will be a data report which will comprise the following sections;

# %% [markdown]
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Preparation
# 4. Analysis
# 5. Recommendation
# 6. Evaluation

# %% [markdown]
# # Import dataset and libraries

# %%
#importing pandas library 
import pandas as pd

#importing numpy library
import numpy as np

# %%
df = pd.read_csv('/content/Autolib_dataset.csv')

# %% [markdown]
# **Previewing the dataset**

# %%
df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
# 5                8 Boulevard Voltaire     0                0  ...    6     7       2
# 6                      37 rue Leblanc     0                0  ...    8    18      20
# 7         17 Rue des Luaps Prolong̩e     3                3  ...    4    22      13
# 8               34 avenue Jean Moulin     1                1  ...    2    22      58
# 9        41 boulevard de Rochechouart     6                6  ...    4    15       2
#
# [10 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
df.shape
# Out:
# (5000, 25)

# %% [markdown]
# #Data Cleaning
#
#
# Starting with validity

# %%
#dropping the columns i wont use, ill make a new dataframe without them
df1 = df

df1.drop(['year','Scheduled at','Displayed comment','Geo point'], axis = 1, inplace = True)
#drop the ones with a broken 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   ID                   5000 non-null   object
#  9   Kind                 5000 non-null   object
#  10  Postal code          5000 non-null   int64
#  11  Public name          5000 non-null   object
#  12  Rental status        5000 non-null   object
#  13  Slots                5000 non-null   int64
#  14  Station type         5000 non-null   object
# ...

# %%
#drop the ones with a broken rental status as they dont have an resources allocated to them
df1.drop(df1[df1['Rental status'] == 'broken'].index, inplace= True)
df1['Rental status']
# Out:
# 0       operational
# 1       operational
# 2       operational
# 3       operational
# 4       operational
#            ...
# 4995    operational
# 4996    operational
# 4997    operational
# 4998    operational
# 4999    operational
# Name: Rental status, Length: 4668, dtype: object

# %%
#dropping these as they are not required to answer any questions
df1.drop(['Subscription status','month','Charging Status'], axis = 1, inplace= True)
df1.head(5)
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
#
# [5 rows x 18 columns]

# %%
df1.drop(['ID'], axis = 1, inplace= True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4668 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Address             4668 non-null   object
#  1   Cars                4668 non-null   int64
#  2   Bluecar counter     4668 non-null   int64
#  3   Utilib counter      4668 non-null   int64
#  4   Utilib 1.4 counter  4668 non-null   int64
#  5   Charge Slots        4668 non-null   int64
#  6   City                4668 non-null   object
#  7   Kind                4668 non-null   object
#  8   Postal code         4668 non-null   int64
#  9   Public name         4668 non-null   object
#  10  Rental status       4668 non-null   object
#  11  Slots               4668 non-null   int64
#  12  Station type        4668 non-null   object
#  13  Status              4668 non-null   object
#  14  day                 4668 non-null   int64
# ...

# %%
df1.drop(['Cars'], axis = 1, inplace= True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4668 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Address             4668 non-null   object
#  1   Bluecar counter     4668 non-null   int64
#  2   Utilib counter      4668 non-null   int64
#  3   Utilib 1.4 counter  4668 non-null   int64
#  4   Charge Slots        4668 non-null   int64
#  5   City                4668 non-null   object
#  6   Kind                4668 non-null   object
#  7   Postal code         4668 non-null   int64
#  8   Public name         4668 non-null   object
#  9   Rental status       4668 non-null   object
#  10  Slots               4668 non-null   int64
#  11  Station type        4668 non-null   object
#  12  Status              4668 non-null   object
#  13  day                 4668 non-null   int64
#  14  hour                4668 non-null   int64
# ...

# %% [markdown]
# The next step is to determine the
# #Completeness & Uniformity

# %%
#checking for any blank spaces
df1.isnull().any()
# Out:
# Address               False
# Bluecar counter       False
# Utilib counter        False
# Utilib 1.4 counter    False
# Charge Slots          False
# City                  False
# Kind                  False
# Postal code           False
# Public name           False
# Rental status         False
# Slots                 False
# Station type          False
# Status                False
# day                   False
# hour                  False
# minute                False
# dtype: bool

# %%
#checking for any duplicates
df1.duplicated().any()
# Out:
# False

# %%
df1.head(5)
# Out:
#                               Address  Bluecar counter  ...  hour minute
# 0                 2 Avenue de Suffren                0  ...    11     43
# 1           145 Rue Raymond Losserand                6  ...     7     24
# 3              51 Rue Eug̬ne Oudin̩                3  ...     4     37
# 4  6 avenue de la Porte de Champerret                3  ...    17     23
# 5                8 Boulevard Voltaire                0  ...     7      2
#
# [5 rows x 13 columns]

# %%
#creating a data frame with just blue car information
dfBlue = df1
dfBlue.drop(['Utilib counter','Utilib 1.4 counter'], axis = 1, inplace = True)

# %%
dfBlue.head(5)
dfBlue.shape
# Out:
#                               Address  Bluecar counter  ...  hour minute
# 0                 2 Avenue de Suffren                0  ...    11     43
# 1           145 Rue Raymond Losserand                6  ...     7     24
# 2    2 Avenue John Fitzgerald Kennedy                3  ...    20     14
# 3              51 Rue Eug̬ne Oudin̩                3  ...     4     37
# 4  6 avenue de la Porte de Champerret                3  ...    17     23
#
# [5 rows x 13 columns]

# %% [markdown]
# #Beginning the analysis of the dataset

# %%
#the first step is isolating only the rides that ocured in paris in april 2018
dfBlue.drop(dfBlue[dfBlue['City'] != 'Paris'].index, inplace= True)
dfBlue['City']
# Out:
# 0       Paris
# 1       Paris
# 3       Paris
# 4       Paris
# 5       Paris
#         ...
# 4992    Paris
# 4994    Paris
# 4996    Paris
# 4997    Paris
# 4999    Paris
# Name: City, Length: 2641, dtype: object

# %%
#well begin by grouping by the hours in order to see hours where the rides are most popular
hourGroup = dfBlue.groupby('hour').count()
hourGroup
# Out:
#       Address  Bluecar counter  Charge Slots  ...  Status  day  minute
# hour                                          ...
# 0         102              102           102  ...     102  102     102
# 1          98               98            98  ...      98   98      98
# 2         112              112           112  ...     112  112     112
# 3         112              112           112  ...     112  112     112
# 4         108              108           108  ...     108  108     108
# 5         113              113           113  ...     113  113     113
# 6         119              119           119  ...     119  119     119
# 7         113              113           113  ...     113  113     113
# 8         122              122           122  ...     122  122     122
# 9         115              115           115  ...     115  115     115
# 10        111              111           111  ...     111  111     111
# ...

# %%
srthourG = hourGroup.sort_values('Bluecar counter', ascending= False)
srthourG
# Out:
#       Address  Bluecar counter  Charge Slots  ...  Status  day  minute
# hour                                          ...
# 21        132              132           132  ...     132  132     132
# 8         122              122           122  ...     122  122     122
# 16        120              120           120  ...     120  120     120
# 6         119              119           119  ...     119  119     119
# 9         115              115           115  ...     115  115     115
# 12        113              113           113  ...     113  113     113
# 5         113              113           113  ...     113  113     113
# 7         113              113           113  ...     113  113     113
# 2         112              112           112  ...     112  112     112
# 3         112              112           112  ...     112  112     112
# 10        111              111           111  ...     111  111     111
# ...

# %% [markdown]
# There was 132 cars ordered in the 21st(9 pm) hour of all the days in the month of April 2018. This is the busyest of all hour slots

# %% [markdown]
# Well now move to the bonus questions

# %%
#What is the most popular hour for returning cars?
#The logic behind the code below is that most popular hour to return cars is when the parking slots are all full?
#well first group by slots and the number of cars counter
2ndgroup = dfBlue.groupby(['hour', 'Slots']).count()
#well then sort by the hour and ascending oder
2ndgroup.sort_values('')
# Out:
#             Address  Bluecar counter  Charge Slots  ...  Status  day  minute
# hour Slots                                          ...
# 0    0           23               23            23  ...      23   23      23
#      1           20               20            20  ...      20   20      20
#      2           11               11            11  ...      11   11      11
#      3           17               17            17  ...      17   17      17
#      4           15               15            15  ...      15   15      15
# ...             ...              ...           ...  ...     ...  ...     ...
# 23   2           15               15            15  ...      15   15      15
#      3           15               15            15  ...      15   15      15
#      4           13               13            13  ...      13   13      13
#      5           16               16            16  ...      16   16      16
# ...

# %%
#What station is the most popular? Overall
df1
PopGroup = dfBlue.groupby(['Postal code','Bluecar counter']).count()
PopGroup.sort_values('Bluecar counter', ascending = False)
# Out:
#                              Address  Charge Slots  City  ...  day  hour  minute
# Postal code Bluecar counter                               ...
# 75011       7                      2             2     2  ...    2     2       2
# 75003       6                      1             1     1  ...    1     1       1
# 75020       6                     15            15    15  ...   15    15      15
# 75019       6                      4             4     4  ...    4     4       4
# 75018       6                     10            10    10  ...   10    10      10
# ...                              ...           ...   ...  ...  ...   ...     ...
# 75015       0                     54            54    54  ...   54    54      54
# 75016       0                     41            41    41  ...   41    41      41
# 75017       0                     42            42    42  ...   42    42      42
# 75002       0                     37            37    37  ...   37    37      37
# ...

# %% [markdown]
# The station at postal code 75011 was the most popular

# %%
df1.head(5)
dfRed = df1
stationPop = dfRed.groupby(['Public name', 'Bluecar counter','Utilib counter','Utilib 1.4 counter']).count()
stationPop.sort_values('Bluecar counter', ascending = False).head(15)
# Out:
#                                                                                           Address  ...  minute
# Public name                            Bluecar counter Utilib counter Utilib 1.4 counter           ...
# V̩lizy-Villacoublay/Paul Dautier/2    7               0              0                         2  ...       2
# Paris/Renault/2                        7               0              0                         2  ...       2
# Versailles/Bonne Aventure/68           7               0              0                         2  ...       2
# Colombes/Parc Lagrav̬re/1             7               0              0                         1  ...       1
# Sceaux/Franklin Roosevelt/60           7               0              0                         1  ...       1
# Nanterre/Lavoisier/14                  7               0              0                         1  ...       1
# ...

# %% [markdown]
# Its not possible to tell which station is the most popular as a number of the have the same number of cars utilize them

# %%
#Finding if the postal code is found is part of the most popular list 
result = dfRed[dfRed['Postal code'] == 75011]
result.groupby(['Public name']).count()
#theres a large number of stations in this postal code
# Out:
#                                    Address  Bluecar counter  ...  hour  minute
# Public name                                                  ...
# Paris/Commandant Lamy/2                  7                7  ...     7       7
# Paris/Faidherbe/27                       5                5  ...     5       5
# Paris/Fran̤ois de Neufchateau/11        4                4  ...     4       4
# Paris/Ledru Rollin/104                   4                4  ...     4       4
# Paris/Ledru Rollin/155                   5                5  ...     5       5
# Paris/L̩on Frot/1                       2                2  ...     2       2
# Paris/Parmentier/125                     6                6  ...     6       6
# Paris/Parmentier/2                       6                6  ...     6       6
# Paris/Parmentier/62                      4                4  ...     4       4
# Paris/Philippe Auguste/1                 3                3  ...     3       3
# ...
